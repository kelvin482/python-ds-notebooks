# %% [markdown]
# # 05 — NumPy Basics
#
# ## Learning goals
# - Create and manipulate arrays
# - Perform vectorized math
# - Understand axis-based operations

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Std:", arr.std())
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Std: 1.4142135623730951

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
print("Matrix:\n", matrix)
print("Column sums:", matrix.sum(axis=0))
print("Row sums:", matrix.sum(axis=1))
# Out:
# Matrix:
#  [[1 2 3]
#  [4 5 6]]
# Column sums: [5 7 9]
# Row sums: [ 6 15]

# %%
# Practice task solution:
import numpy as np

random_values = np.random.rand(100)
print("Min:", random_values.min())
print("Max:", random_values.max())
print("Mean:", random_values.mean())
# Out:
# Min: 0.006065558741166321
# Max: 0.9876255146701569
# Mean: 0.5250593163578013
